# %%
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import gc
from sklearn.model_selection import StratifiedKFold

# %%
train_data = pd.read_csv('./train_dataset/train_public.csv')
test_public = pd.read_csv('./test_public.csv')
train_internet = pd.read_csv('./train_dataset/train_internet.csv')

# %%
train_data.shape
# Out:
# (10000, 39)

# %%
X_train = train_data.copy()
X_test = test_public.copy()

# %%
X_train = X_train.drop(['isDefault'], axis = 1)
X_train.shape
# Out:
# (10000, 38)

# %%
X_train['is_train'] = 1
X_test['is_train'] = 0

X_traintest = X_traintest = pd.concat([X_train, X_test], axis = 0)
X_traintest.shape
# Out:
# (15000, 39)

# %% [markdown]
# ### 特征工程

# %% [markdown]
# #### work_year, class

# %%
work_year_dict = {
    '< 1 year': 0,
    '1 year': 1,
    '2 years': 2,
    '3 years': 3,
    '4 years': 4,
    '5 years': 5,
    '6 years': 6,
    '7 years': 7,
    '8 years': 8,
    '9 years': 9,
    '10+ years': 10,
}

# train_data['work_year'] = train_data['work_year'].map(work_year_dict)
# test_public['work_year'] = test_public['work_year'].map(work_year_dict)
# train_data['work_year'] = train_data['work_year'].fillna(-1)
# test_public['work_year'] = test_public['work_year'].fillna(-1)
# train_internet['work_year'] = train_internet['work_year'].map(work_year_dict)
# train_internet['work_year'] = train_internet['work_year'].fillna(-1)

X_traintest['num_work_year'] = X_traintest['work_year'].map(work_year_dict)

# %%
class_dict = {
    'A': 1,
    'B': 2,
    'C': 3,
    'D': 4,
    'E': 5,
    'F': 6,
    'G': 7,
}

# train_data['class'] = train_data['class'].map(class_dict)
# test_public['class'] = test_public['class'].map(class_dict)
# train_internet['class'] = train_internet['class'].map(class_dict)

X_traintest['num_class'] = X_traintest['class'].map(class_dict)

# %% [markdown]
# #### issue_date, earlies_credit_mon

# %%
# train_data['issue_date'] = pd.to_datetime(train_data['issue_date'])
# test_public['issue_date'] = pd.to_datetime(test_public['issue_date'])
# train_internet['issue_date'] = pd.to_datetime(train_internet['issue_date'])

# train_data['issue_date_month'] = train_data['issue_date'].dt.month
# test_public['issue_date_month'] = train_data['issue_date'].dt.month
# train_internet['issue_date_month'] = train_internet['issue_date'].dt.month

# train_data['issue_date_dayofweek'] = train_data['issue_date'].dt.dayofweek
# test_public['issue_date_dayofweek'] = train_data['issue_date'].dt.dayofweek
# train_internet['issue_date_dayofweek'] = train_internet['issue_date'].dt.dayofweek

X_traintest['issue_date'] = pd.to_datetime(X_traintest['issue_date'])

X_traintest['issue_date_month'] = X_traintest['issue_date'].dt.month

X_traintest['issue_date_dayofweek'] = X_traintest['issue_date'].dt.dayofweek

# %%
X_traintest['earlies_credit_mon'] = pd.to_datetime(X_traintest['earlies_credit_mon'].map(findDig))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39068/372417097.py in <module>
#       1 for data in (X_traintest):
# ----> 2     data['earlies_credit_mon'] = pd.to_datetime(data['earlies_credit_mon'])
#       3
#
# TypeError: string indices must be integers

# %%
train_data['earlies_credit_mon'] = pd.to_datetime(train_data['earlies_credit_mon'])
train_data['earlies_credit_Mon'] = train_data['earlies_credit_mon'].dt.month
train_data['earlies_credit_Year'] = train_data['earlies_credit_mon'].dt.year

# %%
train_data['earlies_credit_Mon']
# Out:
# 0       12
# 1        4
# 2       10
# 3        6
# 4        5
#         ..
# 9995     2
# 9996     5
# 9997     2
# 9998    10
# 9999     2
# Name: earlies_credit_Mon, Length: 10000, dtype: int64

# %%
test_public['earlies_credit_mon'] = pd.to_datetime(test_public['earlies_credit_mon'])
test_public['earlies_credit_Mon'] = test_public['earlies_credit_mon'].dt.month
test_public['earlies_credit_Year'] = test_public['earlies_credit_mon'].dt.year

train_internet['earlies_credit_mon'] = pd.to_datetime(train_internet['earlies_credit_mon'])
train_internet['earlies_credit_Mon'] = train_internet['earlies_credit_mon'].dt.month
train_internet['earlies_credit_Year'] = train_internet['earlies_credit_mon'].dt.year

# %%
col_to_drop = ['issue_date', 'earlies_credit_mon', 'issue_date_month', 'earlies_credit_Mon','earlies_credit_Year']
train_data = train_data.drop(col_to_drop, axis=1)
test_public = test_public.drop(col_to_drop, axis=1)
train_internet = train_internet.drop(col_to_drop, axis=1 )

# %% [markdown]
# #### employer_type, industry

# %%
from sklearn.preprocessing import LabelEncoder

cat_cols = ['employer_type', 'industry']
for col in cat_cols:
    lbl = LabelEncoder().fit(train_data[col])
    train_data[col] = lbl.transform(train_data[col])
    test_public[col] = lbl.transform(test_public[col])
    train_internet[col] = lbl.transform(train_internet[col])

# %%
train_data['industry']
# Out:
# 0       13
# 1       13
# 2        3
# 3       10
# 4        2
#         ..
# 9995     7
# 9996     4
# 9997     2
# 9998     4
# 9999     2
# Name: industry, Length: 10000, dtype: int32

# %% [markdown]
# #### Internet表补充

# %%
tr_cols = set(train_data.columns)
same_col = list(tr_cols.intersection(set(train_internet.columns)))
train_inteSame = train_internet[same_col].copy()

Inte_add_cos = list(tr_cols.difference(set(same_col)))
for col in Inte_add_cos:
    train_inteSame[col] = np.nan

# %% [markdown]
# ### 模型

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb

# %%
from sklearn.model_selection import ShuffleSplit

def train_model(data_, test_, y_, folds_):
    oof_preds = np.zeros(data_.shape[0])
    sub_preds = np.zeros(test_.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in data_.columns if f not in ['loan_id', 'user_id', 'isDefault'] ]
    for n_fold, (trn_idx, val_idx) in enumerate(folds_.split(data_)):
        trn_x, trn_y = data_[feats].iloc[trn_idx], y_.iloc[trn_idx]
        val_x, val_y = data_[feats].iloc[val_idx], y_.iloc[val_idx]
        clf = LGBMClassifier(
            n_estimators=4000,
            learning_rate=0.08,
            num_leaves=2**5,
            colsample_bytree=.65,
            subsample=.9,
            max_depth=5,
#             max_bin=250,
            reg_alpha=.3,
            reg_lambda=.3,
            min_split_gain=.01,
            min_child_weight=2,
            silent=-1,
            verbose=-1,
        )
        
        clf.fit(trn_x, trn_y, 
                eval_set= [(trn_x, trn_y), (val_x, val_y)], 
                eval_metric='auc', verbose=100, early_stopping_rounds=50  #30
               )

        oof_preds[val_idx] = clf.predict_proba(val_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test_[feats], num_iteration=clf.best_iteration_)[:, 1] / folds_.n_splits
        
        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(val_y, oof_preds[val_idx])))
        del clf, trn_x, trn_y, val_x, val_y
        gc.collect()
        
    print('Full AUC score %.6f' % roc_auc_score(y_, oof_preds)) 
    
    test_['isDefault'] = sub_preds

    return oof_preds, test_[['loan_id', 'isDefault']], feature_importance_df
    
def display_importances(feature_importance_df_):
    # Plot feature importances
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:50].index
    
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    
    plt.figure(figsize=(8,10))
    sns.barplot(x="importance", y="feature", 
                data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances.png')

# %%
train_label = train_data['isDefault']
folds = KFold(n_splits=5, shuffle=True, random_state=546789)

# %%
oof_preds, IntePre, importances = train_model(train_data, train_inteSame, train_label, folds)
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.955788	training's binary_logloss: 0.221644	valid_1's auc: 0.889459	valid_1's binary_logloss: 0.293621
# Early stopping, best iteration is:
# [75]	training's auc: 0.943318	training's binary_logloss: 0.237837	valid_1's auc: 0.890434	valid_1's binary_logloss: 0.29229
# Fold  1 AUC : 0.890434
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.952455	training's binary_logloss: 0.227972	valid_1's auc: 0.88807	valid_1's binary_logloss: 0.290497
# Early stopping, best iteration is:
# [73]	training's auc: 0.941306	training's binary_logloss: 0.241807	valid_1's auc: 0.889551	valid_1's binary_logloss: 0.289273
# Fold  2 AUC : 0.889551
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.951544	training's binary_logloss: 0.225107	valid_1's auc: 0.87341	valid_1's binary_logloss: 0.313308
# Early stopping, best iteration is:
# [81]	training's auc: 0.945248	training's binary_logloss: 0.233439	valid_1's auc: 0.873967	valid_1's binary_logloss: 0.312447
# Fold  3 AUC : 0.873967
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.954584	training's binary_logloss: 0.221665	valid_1's auc: 0.866816	valid_1's binary_logloss: 0.321172
# Early stopping, best iteration is:
# [57]	training's auc: 0.936263	training's binary_logloss: 0.245938	valid_1's auc: 0.868299	valid_1's binary_logloss: 0.318315
# Fold  4 AUC : 0.868299
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.952337	training's binary_logloss: 0.227556	valid_1's auc: 0.874974	valid_1's binary_logloss: 0.304572
# Early stopping, best iteration is:
# [76]	training's auc: 0.939919	training's binary_logloss: 0.242462	valid_1's auc: 0.877343	valid_1's binary_logloss: 0.301593
# Fold  5 AUC : 0.877343
# Full AUC score 0.879609

# %%
# from sklearn.datasets import load_iris
# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV  # Perforing grid search
# from sklearn.model_selection import train_test_split




# parameters = {
#               'num_leaves': [60, 65, 70, 80, 100, 2**7]
# }
# clf = LGBMClassifier(
#             n_estimators=4000,
#             learning_rate=0.09,
#             num_leaves=90,
#             colsample_bytree=.65,
#             subsample=.9,
#             max_depth=7,
# #             max_bin=250,
#             reg_alpha=.1,
#             reg_lambda=.3,
#             min_split_gain=.01,
#             min_child_weight=2,
#             silent=-1,
#             verbose=-1,
#         )
# gsearch = GridSearchCV(gbm, param_grid=parameters, scoring='accuracy', cv=3)
# gsearch.fit(train_data, train_label)

# print("Best score: %0.3f" % gsearch.best_score_)
# print("Best parameters set:")
# best_parameters = gsearch.best_estimator_.get_params()
# for param_name in sorted(parameters.keys()):
#     print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
IntePre['isDef'] = train_internet['is_default']
# Out:
# E:\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(IntePre['isDef'],IntePre.isDefault)
# Out:
# 0.729664607024783

# %%
InteId = IntePre.loc[IntePre.isDefault<0.5, 'loan_id'].tolist()

train_data['dataSourse'] = 1
test_public['dataSourse'] = 1
train_inteSame['dataSourse'] = 0
train_inteSame['isDefault'] = train_internet['is_default']
use_te = train_inteSame[train_inteSame.loan_id.isin( InteId )].copy()
data = pd.concat([ train_data,test_public,use_te]).reset_index(drop=True)

# %%
# plt.figure(figsize=(16,6))
# plt.title("Distribution of Default values IntePre")
# sns.distplot(IntePre['isDefault'],color="black", kde=True,bins=120, label='train_data')
# # sns.distplot(train_inte[col],color="red", kde=True,bins=120, label='train_inte')
# plt.legend();plt.show()

# %%
train = data[data['isDefault'].notna()]
test  = data[data['isDefault'].isna()]
# for col in ['sub_class', 'work_type']:
#     del train[col]
#     del test[col]


del data
del train_data,test_public


y = train['isDefault']
folds = KFold(n_splits=100, shuffle=True, random_state=546789)
oof_preds, test_preds, importances = train_model(train, test, y, folds)
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805605	training's binary_logloss: 0.236921	valid_1's auc: 0.785157	valid_1's binary_logloss: 0.245956
# [200]	training's auc: 0.816875	training's binary_logloss: 0.232444	valid_1's auc: 0.786345	valid_1's binary_logloss: 0.245633
# Early stopping, best iteration is:
# [160]	training's auc: 0.812969	training's binary_logloss: 0.234023	valid_1's auc: 0.786987	valid_1's binary_logloss: 0.245321
# Fold  1 AUC : 0.786987
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805524	training's binary_logloss: 0.237028	valid_1's auc: 0.797371	valid_1's binary_logloss: 0.236343
# Early stopping, best iteration is:
# [106]	training's auc: 0.806548	training's binary_logloss: 0.236643	valid_1's auc: 0.797961	valid_1's binary_logloss: 0.236177
# Fold  2 AUC : 0.797961
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805664	training's binary_logloss: 0.236709	valid_1's auc: 0.812795	valid_1's binary_logloss: 0.258587
# Early stopping, best iteration is:
# [140]	training's auc: 0.810869	training's binary_logloss: 0.23464	valid_1's auc: 0.814211	valid_1's binary_logloss: 0.257726
# Fold  3 AUC : 0.814211
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805659	training's binary_logloss: 0.236763	valid_1's auc: 0.789239	valid_1's binary_logloss: 0.258501
# [200]	training's auc: 0.816658	training's binary_logloss: 0.232344	valid_1's auc: 0.789855	valid_1's binary_logloss: 0.257576
# Early stopping, best iteration is:
# [169]	training's auc: 0.813707	training's binary_logloss: 0.233519	valid_1's auc: 0.790176	valid_1's binary_logloss: 0.257601
# Fold  4 AUC : 0.790176
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805426	training's binary_logloss: 0.236895	valid_1's auc: 0.800309	valid_1's binary_logloss: 0.249554
# [200]	training's auc: 0.81695	training's binary_logloss: 0.232339	valid_1's auc: 0.801941	valid_1's binary_logloss: 0.248758
# [300]	training's auc: 0.825475	training's binary_logloss: 0.228928	valid_1's auc: 0.802871	valid_1's binary_logloss: 0.248126
# Early stopping, best iteration is:
# [298]	training's auc: 0.825279	training's binary_logloss: 0.228999	valid_1's auc: 0.802992	valid_1's binary_logloss: 0.248078
# Fold  5 AUC : 0.802992
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805319	training's binary_logloss: 0.237091	valid_1's auc: 0.817473	valid_1's binary_logloss: 0.228373
# Early stopping, best iteration is:
# [129]	training's auc: 0.809522	training's binary_logloss: 0.235484	valid_1's auc: 0.81949	valid_1's binary_logloss: 0.227619
# Fold  6 AUC : 0.819490
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805485	training's binary_logloss: 0.237124	valid_1's auc: 0.790947	valid_1's binary_logloss: 0.230355
# [200]	training's auc: 0.816649	training's binary_logloss: 0.232682	valid_1's auc: 0.792124	valid_1's binary_logloss: 0.229758
# Early stopping, best iteration is:
# [182]	training's auc: 0.814967	training's binary_logloss: 0.233371	valid_1's auc: 0.793214	valid_1's binary_logloss: 0.229402
# Fold  7 AUC : 0.793214
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805828	training's binary_logloss: 0.236834	valid_1's auc: 0.788972	valid_1's binary_logloss: 0.245699
# [200]	training's auc: 0.816723	training's binary_logloss: 0.232393	valid_1's auc: 0.790213	valid_1's binary_logloss: 0.245287
# Early stopping, best iteration is:
# [196]	training's auc: 0.816452	training's binary_logloss: 0.232515	valid_1's auc: 0.790526	valid_1's binary_logloss: 0.24521
# Fold  8 AUC : 0.790526
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805735	training's binary_logloss: 0.236992	valid_1's auc: 0.784343	valid_1's binary_logloss: 0.232706
# [200]	training's auc: 0.816876	training's binary_logloss: 0.232586	valid_1's auc: 0.785005	valid_1's binary_logloss: 0.232347
# Early stopping, best iteration is:
# [179]	training's auc: 0.815015	training's binary_logloss: 0.233327	valid_1's auc: 0.785445	valid_1's binary_logloss: 0.232236
# Fold  9 AUC : 0.785445
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805268	training's binary_logloss: 0.23704	valid_1's auc: 0.807866	valid_1's binary_logloss: 0.237505
# [200]	training's auc: 0.816843	training's binary_logloss: 0.232478	valid_1's auc: 0.810286	valid_1's binary_logloss: 0.236355
# Early stopping, best iteration is:
# [203]	training's auc: 0.817063	training's binary_logloss: 0.232374	valid_1's auc: 0.810313	valid_1's binary_logloss: 0.23633
# Fold 10 AUC : 0.810313
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805434	training's binary_logloss: 0.237046	valid_1's auc: 0.786196	valid_1's binary_logloss: 0.233934
# [200]	training's auc: 0.817153	training's binary_logloss: 0.232428	valid_1's auc: 0.78888	valid_1's binary_logloss: 0.233154
# Early stopping, best iteration is:
# [204]	training's auc: 0.817763	training's binary_logloss: 0.232213	valid_1's auc: 0.789127	valid_1's binary_logloss: 0.233115
# Fold 11 AUC : 0.789127
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805762	training's binary_logloss: 0.236687	valid_1's auc: 0.773325	valid_1's binary_logloss: 0.266103
# Early stopping, best iteration is:
# [84]	training's auc: 0.803256	training's binary_logloss: 0.237723	valid_1's auc: 0.773854	valid_1's binary_logloss: 0.26592
# Fold 12 AUC : 0.773854
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805786	training's binary_logloss: 0.236928	valid_1's auc: 0.794736	valid_1's binary_logloss: 0.237219
# [200]	training's auc: 0.816982	training's binary_logloss: 0.232456	valid_1's auc: 0.796629	valid_1's binary_logloss: 0.236425
# Early stopping, best iteration is:
# [226]	training's auc: 0.819246	training's binary_logloss: 0.231534	valid_1's auc: 0.797762	valid_1's binary_logloss: 0.236228
# Fold 13 AUC : 0.797762
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805595	training's binary_logloss: 0.236908	valid_1's auc: 0.809737	valid_1's binary_logloss: 0.240803
# [200]	training's auc: 0.816659	training's binary_logloss: 0.232479	valid_1's auc: 0.811535	valid_1's binary_logloss: 0.239547
# Early stopping, best iteration is:
# [177]	training's auc: 0.814521	training's binary_logloss: 0.233342	valid_1's auc: 0.812345	valid_1's binary_logloss: 0.23941
# Fold 14 AUC : 0.812345
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805351	training's binary_logloss: 0.237039	valid_1's auc: 0.811278	valid_1's binary_logloss: 0.235928
# [200]	training's auc: 0.816418	training's binary_logloss: 0.232603	valid_1's auc: 0.812631	valid_1's binary_logloss: 0.234878
# Early stopping, best iteration is:
# [172]	training's auc: 0.813676	training's binary_logloss: 0.233679	valid_1's auc: 0.81314	valid_1's binary_logloss: 0.234692
# Fold 15 AUC : 0.813140
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805832	training's binary_logloss: 0.236815	valid_1's auc: 0.782478	valid_1's binary_logloss: 0.245921
# Early stopping, best iteration is:
# [102]	training's auc: 0.806236	training's binary_logloss: 0.23667	valid_1's auc: 0.782544	valid_1's binary_logloss: 0.245913
# Fold 16 AUC : 0.782544
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805968	training's binary_logloss: 0.236792	valid_1's auc: 0.775977	valid_1's binary_logloss: 0.249424
# Early stopping, best iteration is:
# [133]	training's auc: 0.81042	training's binary_logloss: 0.235025	valid_1's auc: 0.776903	valid_1's binary_logloss: 0.249249
# Fold 17 AUC : 0.776903
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805628	training's binary_logloss: 0.236819	valid_1's auc: 0.794334	valid_1's binary_logloss: 0.25169
# [200]	training's auc: 0.816502	training's binary_logloss: 0.232445	valid_1's auc: 0.798912	valid_1's binary_logloss: 0.25047
# [300]	training's auc: 0.824798	training's binary_logloss: 0.229089	valid_1's auc: 0.800176	valid_1's binary_logloss: 0.250474
# Early stopping, best iteration is:
# [260]	training's auc: 0.821477	training's binary_logloss: 0.230434	valid_1's auc: 0.800268	valid_1's binary_logloss: 0.250192
# Fold 18 AUC : 0.800268
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805348	training's binary_logloss: 0.236898	valid_1's auc: 0.802992	valid_1's binary_logloss: 0.247998
# [200]	training's auc: 0.816241	training's binary_logloss: 0.232576	valid_1's auc: 0.806871	valid_1's binary_logloss: 0.246164
# [300]	training's auc: 0.824836	training's binary_logloss: 0.229102	valid_1's auc: 0.807019	valid_1's binary_logloss: 0.245868
# Early stopping, best iteration is:
# [280]	training's auc: 0.823209	training's binary_logloss: 0.229769	valid_1's auc: 0.807645	valid_1's binary_logloss: 0.245717
# Fold 19 AUC : 0.807645
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.8057	training's binary_logloss: 0.237002	valid_1's auc: 0.809458	valid_1's binary_logloss: 0.226474
# Early stopping, best iteration is:
# [88]	training's auc: 0.80354	training's binary_logloss: 0.237838	valid_1's auc: 0.809578	valid_1's binary_logloss: 0.226573
# Fold 20 AUC : 0.809578
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.8054	training's binary_logloss: 0.237163	valid_1's auc: 0.794186	valid_1's binary_logloss: 0.222018
# [200]	training's auc: 0.816459	training's binary_logloss: 0.23271	valid_1's auc: 0.797421	valid_1's binary_logloss: 0.221349
# [300]	training's auc: 0.824954	training's binary_logloss: 0.229216	valid_1's auc: 0.80054	valid_1's binary_logloss: 0.220613
# [400]	training's auc: 0.83239	training's binary_logloss: 0.226167	valid_1's auc: 0.801621	valid_1's binary_logloss: 0.220354
# [500]	training's auc: 0.83911	training's binary_logloss: 0.223285	valid_1's auc: 0.802596	valid_1's binary_logloss: 0.220211
# [600]	training's auc: 0.845346	training's binary_logloss: 0.22059	valid_1's auc: 0.802945	valid_1's binary_logloss: 0.220277
# Early stopping, best iteration is:
# [551]	training's auc: 0.842305	training's binary_logloss: 0.221928	valid_1's auc: 0.803407	valid_1's binary_logloss: 0.22
# Fold 21 AUC : 0.803407
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.804948	training's binary_logloss: 0.237404	valid_1's auc: 0.825503	valid_1's binary_logloss: 0.20715
# Early stopping, best iteration is:
# [139]	training's auc: 0.810152	training's binary_logloss: 0.235375	valid_1's auc: 0.826962	valid_1's binary_logloss: 0.206388
# Fold 22 AUC : 0.826962
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805551	training's binary_logloss: 0.237089	valid_1's auc: 0.800729	valid_1's binary_logloss: 0.227414
# [200]	training's auc: 0.816192	training's binary_logloss: 0.232762	valid_1's auc: 0.804479	valid_1's binary_logloss: 0.226203
# Early stopping, best iteration is:
# [182]	training's auc: 0.814787	training's binary_logloss: 0.233367	valid_1's auc: 0.804703	valid_1's binary_logloss: 0.226146
# Fold 23 AUC : 0.804703
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805467	training's binary_logloss: 0.236794	valid_1's auc: 0.7883	valid_1's binary_logloss: 0.257522
# [200]	training's auc: 0.816683	training's binary_logloss: 0.232331	valid_1's auc: 0.791877	valid_1's binary_logloss: 0.256332
# [300]	training's auc: 0.825171	training's binary_logloss: 0.228917	valid_1's auc: 0.794352	valid_1's binary_logloss: 0.255367
# [400]	training's auc: 0.832728	training's binary_logloss: 0.225816	valid_1's auc: 0.795921	valid_1's binary_logloss: 0.254808
# Early stopping, best iteration is:
# [392]	training's auc: 0.832176	training's binary_logloss: 0.226067	valid_1's auc: 0.796214	valid_1's binary_logloss: 0.254732
# Fold 24 AUC : 0.796214
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.80543	training's binary_logloss: 0.237013	valid_1's auc: 0.808043	valid_1's binary_logloss: 0.236091
# [200]	training's auc: 0.81662	training's binary_logloss: 0.232578	valid_1's auc: 0.81144	valid_1's binary_logloss: 0.234531
# [300]	training's auc: 0.824974	training's binary_logloss: 0.229167	valid_1's auc: 0.813328	valid_1's binary_logloss: 0.233728
# [400]	training's auc: 0.832177	training's binary_logloss: 0.22619	valid_1's auc: 0.8139	valid_1's binary_logloss: 0.233228
# Early stopping, best iteration is:
# [426]	training's auc: 0.833907	training's binary_logloss: 0.225437	valid_1's auc: 0.814267	valid_1's binary_logloss: 0.233082
# Fold 25 AUC : 0.814267
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805302	training's binary_logloss: 0.237043	valid_1's auc: 0.79944	valid_1's binary_logloss: 0.242298
# Early stopping, best iteration is:
# [146]	training's auc: 0.81138	training's binary_logloss: 0.234632	valid_1's auc: 0.800965	valid_1's binary_logloss: 0.241426
# Fold 26 AUC : 0.800965
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805415	training's binary_logloss: 0.236857	valid_1's auc: 0.793125	valid_1's binary_logloss: 0.25477
# [200]	training's auc: 0.816827	training's binary_logloss: 0.232358	valid_1's auc: 0.796435	valid_1's binary_logloss: 0.253633
# Early stopping, best iteration is:
# [220]	training's auc: 0.818398	training's binary_logloss: 0.231697	valid_1's auc: 0.79671	valid_1's binary_logloss: 0.253535
# Fold 27 AUC : 0.796710
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805649	training's binary_logloss: 0.236791	valid_1's auc: 0.789601	valid_1's binary_logloss: 0.254303
# [200]	training's auc: 0.816714	training's binary_logloss: 0.23237	valid_1's auc: 0.792246	valid_1's binary_logloss: 0.253628
# [300]	training's auc: 0.82503	training's binary_logloss: 0.22897	valid_1's auc: 0.794685	valid_1's binary_logloss: 0.253036
# Early stopping, best iteration is:
# [297]	training's auc: 0.824904	training's binary_logloss: 0.229024	valid_1's auc: 0.794839	valid_1's binary_logloss: 0.253011
# Fold 28 AUC : 0.794839
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805592	training's binary_logloss: 0.236935	valid_1's auc: 0.80606	valid_1's binary_logloss: 0.240625
# [200]	training's auc: 0.816844	training's binary_logloss: 0.232437	valid_1's auc: 0.809832	valid_1's binary_logloss: 0.238792
# Early stopping, best iteration is:
# [230]	training's auc: 0.819239	training's binary_logloss: 0.231421	valid_1's auc: 0.810377	valid_1's binary_logloss: 0.238459
# Fold 29 AUC : 0.810377
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805619	training's binary_logloss: 0.237099	valid_1's auc: 0.805414	valid_1's binary_logloss: 0.225693
# Early stopping, best iteration is:
# [128]	training's auc: 0.809219	training's binary_logloss: 0.235622	valid_1's auc: 0.806747	valid_1's binary_logloss: 0.224981
# Fold 30 AUC : 0.806747
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805454	training's binary_logloss: 0.237019	valid_1's auc: 0.795436	valid_1's binary_logloss: 0.236657
# [200]	training's auc: 0.816535	training's binary_logloss: 0.232639	valid_1's auc: 0.799137	valid_1's binary_logloss: 0.235348
# [300]	training's auc: 0.824569	training's binary_logloss: 0.229354	valid_1's auc: 0.800593	valid_1's binary_logloss: 0.234755
# Early stopping, best iteration is:
# [288]	training's auc: 0.823655	training's binary_logloss: 0.229718	valid_1's auc: 0.800884	valid_1's binary_logloss: 0.234629
# Fold 31 AUC : 0.800884
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805683	training's binary_logloss: 0.236942	valid_1's auc: 0.80666	valid_1's binary_logloss: 0.237572
# [200]	training's auc: 0.816713	training's binary_logloss: 0.232549	valid_1's auc: 0.809754	valid_1's binary_logloss: 0.236189
# [300]	training's auc: 0.824945	training's binary_logloss: 0.229173	valid_1's auc: 0.811274	valid_1's binary_logloss: 0.23545
# Early stopping, best iteration is:
# [346]	training's auc: 0.828336	training's binary_logloss: 0.227774	valid_1's auc: 0.811922	valid_1's binary_logloss: 0.235236
# Fold 32 AUC : 0.811922
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805722	training's binary_logloss: 0.236913	valid_1's auc: 0.789011	valid_1's binary_logloss: 0.240388
# [200]	training's auc: 0.816897	training's binary_logloss: 0.232498	valid_1's auc: 0.790608	valid_1's binary_logloss: 0.23978
# Early stopping, best iteration is:
# [175]	training's auc: 0.814814	training's binary_logloss: 0.233343	valid_1's auc: 0.791236	valid_1's binary_logloss: 0.239568
# Fold 33 AUC : 0.791236
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805567	training's binary_logloss: 0.236938	valid_1's auc: 0.809768	valid_1's binary_logloss: 0.24042
# [200]	training's auc: 0.816765	training's binary_logloss: 0.232489	valid_1's auc: 0.812501	valid_1's binary_logloss: 0.238891
# Early stopping, best iteration is:
# [194]	training's auc: 0.816135	training's binary_logloss: 0.232731	valid_1's auc: 0.813102	valid_1's binary_logloss: 0.238757
# Fold 34 AUC : 0.813102
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805329	training's binary_logloss: 0.237098	valid_1's auc: 0.796854	valid_1's binary_logloss: 0.232318
# [200]	training's auc: 0.816794	training's binary_logloss: 0.232566	valid_1's auc: 0.802518	valid_1's binary_logloss: 0.230455
# [300]	training's auc: 0.824765	training's binary_logloss: 0.229288	valid_1's auc: 0.804996	valid_1's binary_logloss: 0.229976
# [400]	training's auc: 0.831883	training's binary_logloss: 0.226345	valid_1's auc: 0.806763	valid_1's binary_logloss: 0.22933
# Early stopping, best iteration is:
# [401]	training's auc: 0.831973	training's binary_logloss: 0.226312	valid_1's auc: 0.806917	valid_1's binary_logloss: 0.229283
# Fold 35 AUC : 0.806917
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805527	training's binary_logloss: 0.236979	valid_1's auc: 0.797148	valid_1's binary_logloss: 0.237842
# [200]	training's auc: 0.816528	training's binary_logloss: 0.232585	valid_1's auc: 0.800289	valid_1's binary_logloss: 0.2362
# [300]	training's auc: 0.824916	training's binary_logloss: 0.229187	valid_1's auc: 0.800243	valid_1's binary_logloss: 0.236244
# Early stopping, best iteration is:
# [274]	training's auc: 0.822945	training's binary_logloss: 0.23	valid_1's auc: 0.800826	valid_1's binary_logloss: 0.235999
# Fold 36 AUC : 0.800826
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805506	training's binary_logloss: 0.23691	valid_1's auc: 0.798643	valid_1's binary_logloss: 0.241305
# [200]	training's auc: 0.817093	training's binary_logloss: 0.232341	valid_1's auc: 0.801318	valid_1's binary_logloss: 0.240244
# [300]	training's auc: 0.825136	training's binary_logloss: 0.22902	valid_1's auc: 0.803353	valid_1's binary_logloss: 0.239385
# [400]	training's auc: 0.832663	training's binary_logloss: 0.2259	valid_1's auc: 0.804789	valid_1's binary_logloss: 0.239026
# Early stopping, best iteration is:
# [405]	training's auc: 0.833101	training's binary_logloss: 0.22573	valid_1's auc: 0.80492	valid_1's binary_logloss: 0.238997
# Fold 37 AUC : 0.804920
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805458	training's binary_logloss: 0.237068	valid_1's auc: 0.809345	valid_1's binary_logloss: 0.226728
# [200]	training's auc: 0.816427	training's binary_logloss: 0.23271	valid_1's auc: 0.811864	valid_1's binary_logloss: 0.225525
# Early stopping, best iteration is:
# [180]	training's auc: 0.814757	training's binary_logloss: 0.233376	valid_1's auc: 0.812533	valid_1's binary_logloss: 0.225375
# Fold 38 AUC : 0.812533
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805927	training's binary_logloss: 0.23692	valid_1's auc: 0.786872	valid_1's binary_logloss: 0.236779
# [200]	training's auc: 0.816813	training's binary_logloss: 0.23247	valid_1's auc: 0.790132	valid_1's binary_logloss: 0.235867
# Early stopping, best iteration is:
# [184]	training's auc: 0.815456	training's binary_logloss: 0.233041	valid_1's auc: 0.790113	valid_1's binary_logloss: 0.235825
# Fold 39 AUC : 0.790113
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805879	training's binary_logloss: 0.236829	valid_1's auc: 0.789145	valid_1's binary_logloss: 0.245255
# [200]	training's auc: 0.81724	training's binary_logloss: 0.232274	valid_1's auc: 0.790465	valid_1's binary_logloss: 0.244968
# Early stopping, best iteration is:
# [153]	training's auc: 0.812639	training's binary_logloss: 0.234162	valid_1's auc: 0.790868	valid_1's binary_logloss: 0.244719
# Fold 40 AUC : 0.790868
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805169	training's binary_logloss: 0.237206	valid_1's auc: 0.798333	valid_1's binary_logloss: 0.225623
# [200]	training's auc: 0.816437	training's binary_logloss: 0.232747	valid_1's auc: 0.806446	valid_1's binary_logloss: 0.223113
# [300]	training's auc: 0.824904	training's binary_logloss: 0.229346	valid_1's auc: 0.808806	valid_1's binary_logloss: 0.222445
# [400]	training's auc: 0.831737	training's binary_logloss: 0.226416	valid_1's auc: 0.810891	valid_1's binary_logloss: 0.221704
# Early stopping, best iteration is:
# [402]	training's auc: 0.831856	training's binary_logloss: 0.226369	valid_1's auc: 0.810986	valid_1's binary_logloss: 0.221679
# Fold 41 AUC : 0.810986
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805458	training's binary_logloss: 0.236996	valid_1's auc: 0.788318	valid_1's binary_logloss: 0.241372
# [200]	training's auc: 0.816572	training's binary_logloss: 0.232543	valid_1's auc: 0.790535	valid_1's binary_logloss: 0.241004
# Early stopping, best iteration is:
# [246]	training's auc: 0.820601	training's binary_logloss: 0.230899	valid_1's auc: 0.791669	valid_1's binary_logloss: 0.240649
# Fold 42 AUC : 0.791669
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805588	training's binary_logloss: 0.236966	valid_1's auc: 0.78715	valid_1's binary_logloss: 0.239533
# Early stopping, best iteration is:
# [127]	training's auc: 0.809134	training's binary_logloss: 0.235546	valid_1's auc: 0.787916	valid_1's binary_logloss: 0.239237
# Fold 43 AUC : 0.787916
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805797	training's binary_logloss: 0.236769	valid_1's auc: 0.79149	valid_1's binary_logloss: 0.254725
# [200]	training's auc: 0.816821	training's binary_logloss: 0.232382	valid_1's auc: 0.794902	valid_1's binary_logloss: 0.253522
# [300]	training's auc: 0.824949	training's binary_logloss: 0.229061	valid_1's auc: 0.795175	valid_1's binary_logloss: 0.253289
# Early stopping, best iteration is:
# [257]	training's auc: 0.821835	training's binary_logloss: 0.230345	valid_1's auc: 0.796163	valid_1's binary_logloss: 0.252919
# Fold 44 AUC : 0.796163
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805771	training's binary_logloss: 0.236866	valid_1's auc: 0.774728	valid_1's binary_logloss: 0.248156
# [200]	training's auc: 0.816441	training's binary_logloss: 0.232591	valid_1's auc: 0.779837	valid_1's binary_logloss: 0.246458
# [300]	training's auc: 0.824502	training's binary_logloss: 0.2293	valid_1's auc: 0.783215	valid_1's binary_logloss: 0.245359
# [400]	training's auc: 0.831955	training's binary_logloss: 0.226223	valid_1's auc: 0.786086	valid_1's binary_logloss: 0.244415
# Early stopping, best iteration is:
# [426]	training's auc: 0.833845	training's binary_logloss: 0.225443	valid_1's auc: 0.787064	valid_1's binary_logloss: 0.244127
# Fold 45 AUC : 0.787064
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805435	training's binary_logloss: 0.237021	valid_1's auc: 0.80466	valid_1's binary_logloss: 0.237491
# [200]	training's auc: 0.816522	training's binary_logloss: 0.232626	valid_1's auc: 0.806019	valid_1's binary_logloss: 0.236704
# [300]	training's auc: 0.824755	training's binary_logloss: 0.229271	valid_1's auc: 0.807647	valid_1's binary_logloss: 0.236069
# Early stopping, best iteration is:
# [257]	training's auc: 0.821446	training's binary_logloss: 0.230624	valid_1's auc: 0.807784	valid_1's binary_logloss: 0.236137
# Fold 46 AUC : 0.807784
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805396	training's binary_logloss: 0.237046	valid_1's auc: 0.79364	valid_1's binary_logloss: 0.238133
# [200]	training's auc: 0.816848	training's binary_logloss: 0.232538	valid_1's auc: 0.799178	valid_1's binary_logloss: 0.236352
# [300]	training's auc: 0.825477	training's binary_logloss: 0.2291	valid_1's auc: 0.800564	valid_1's binary_logloss: 0.235951
# [400]	training's auc: 0.832085	training's binary_logloss: 0.226279	valid_1's auc: 0.801831	valid_1's binary_logloss: 0.235648
# [500]	training's auc: 0.839467	training's binary_logloss: 0.223185	valid_1's auc: 0.802903	valid_1's binary_logloss: 0.235459
# Early stopping, best iteration is:
# [477]	training's auc: 0.83763	training's binary_logloss: 0.223932	valid_1's auc: 0.802844	valid_1's binary_logloss: 0.235371
# Fold 47 AUC : 0.802844
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805326	training's binary_logloss: 0.237033	valid_1's auc: 0.828065	valid_1's binary_logloss: 0.230539
# [200]	training's auc: 0.816158	training's binary_logloss: 0.232664	valid_1's auc: 0.831125	valid_1's binary_logloss: 0.228814
# Early stopping, best iteration is:
# [205]	training's auc: 0.816697	training's binary_logloss: 0.232457	valid_1's auc: 0.831639	valid_1's binary_logloss: 0.228649
# Fold 48 AUC : 0.831639
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805566	training's binary_logloss: 0.236699	valid_1's auc: 0.793838	valid_1's binary_logloss: 0.264076
# [200]	training's auc: 0.816817	training's binary_logloss: 0.232235	valid_1's auc: 0.796191	valid_1's binary_logloss: 0.26337
# [300]	training's auc: 0.825667	training's binary_logloss: 0.228665	valid_1's auc: 0.798261	valid_1's binary_logloss: 0.262569
# [400]	training's auc: 0.832807	training's binary_logloss: 0.225719	valid_1's auc: 0.800139	valid_1's binary_logloss: 0.261849
# Early stopping, best iteration is:
# [388]	training's auc: 0.832029	training's binary_logloss: 0.226057	valid_1's auc: 0.800248	valid_1's binary_logloss: 0.261785
# Fold 49 AUC : 0.800248
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805558	training's binary_logloss: 0.237032	valid_1's auc: 0.787429	valid_1's binary_logloss: 0.234083
# [200]	training's auc: 0.816874	training's binary_logloss: 0.232486	valid_1's auc: 0.792551	valid_1's binary_logloss: 0.232416
# [300]	training's auc: 0.825057	training's binary_logloss: 0.229206	valid_1's auc: 0.795854	valid_1's binary_logloss: 0.23154
# [400]	training's auc: 0.832327	training's binary_logloss: 0.226151	valid_1's auc: 0.796797	valid_1's binary_logloss: 0.231346
# Early stopping, best iteration is:
# [437]	training's auc: 0.835169	training's binary_logloss: 0.224992	valid_1's auc: 0.797279	valid_1's binary_logloss: 0.231086
# Fold 50 AUC : 0.797279
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805728	training's binary_logloss: 0.237003	valid_1's auc: 0.814545	valid_1's binary_logloss: 0.227481
# [200]	training's auc: 0.816654	training's binary_logloss: 0.232617	valid_1's auc: 0.816483	valid_1's binary_logloss: 0.22642
# [300]	training's auc: 0.825176	training's binary_logloss: 0.229174	valid_1's auc: 0.817507	valid_1's binary_logloss: 0.226103
# [400]	training's auc: 0.832667	training's binary_logloss: 0.226089	valid_1's auc: 0.817694	valid_1's binary_logloss: 0.22609
# Early stopping, best iteration is:
# [359]	training's auc: 0.829737	training's binary_logloss: 0.227315	valid_1's auc: 0.818578	valid_1's binary_logloss: 0.225876
# Fold 51 AUC : 0.818578
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.80503	training's binary_logloss: 0.237078	valid_1's auc: 0.827608	valid_1's binary_logloss: 0.232914
# [200]	training's auc: 0.815964	training's binary_logloss: 0.232737	valid_1's auc: 0.830429	valid_1's binary_logloss: 0.231444
# [300]	training's auc: 0.824516	training's binary_logloss: 0.229283	valid_1's auc: 0.831659	valid_1's binary_logloss: 0.230744
# Early stopping, best iteration is:
# [264]	training's auc: 0.8214	training's binary_logloss: 0.230534	valid_1's auc: 0.832132	valid_1's binary_logloss: 0.230732
# Fold 52 AUC : 0.832132
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805238	training's binary_logloss: 0.236967	valid_1's auc: 0.794477	valid_1's binary_logloss: 0.249413
# [200]	training's auc: 0.817171	training's binary_logloss: 0.232331	valid_1's auc: 0.796133	valid_1's binary_logloss: 0.248387
# Early stopping, best iteration is:
# [192]	training's auc: 0.816365	training's binary_logloss: 0.232642	valid_1's auc: 0.796535	valid_1's binary_logloss: 0.248264
# Fold 53 AUC : 0.796535
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805683	training's binary_logloss: 0.236895	valid_1's auc: 0.786583	valid_1's binary_logloss: 0.242741
# [200]	training's auc: 0.817238	training's binary_logloss: 0.232334	valid_1's auc: 0.791763	valid_1's binary_logloss: 0.241006
# [300]	training's auc: 0.825585	training's binary_logloss: 0.228952	valid_1's auc: 0.793045	valid_1's binary_logloss: 0.240802
# Early stopping, best iteration is:
# [298]	training's auc: 0.825433	training's binary_logloss: 0.229013	valid_1's auc: 0.793051	valid_1's binary_logloss: 0.240815
# Fold 54 AUC : 0.793051
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.80591	training's binary_logloss: 0.236723	valid_1's auc: 0.773307	valid_1's binary_logloss: 0.262237
# [200]	training's auc: 0.816581	training's binary_logloss: 0.232421	valid_1's auc: 0.775712	valid_1's binary_logloss: 0.261345
# [300]	training's auc: 0.825294	training's binary_logloss: 0.228916	valid_1's auc: 0.77746	valid_1's binary_logloss: 0.260782
# [400]	training's auc: 0.832563	training's binary_logloss: 0.225869	valid_1's auc: 0.778883	valid_1's binary_logloss: 0.26031
# Early stopping, best iteration is:
# [398]	training's auc: 0.832395	training's binary_logloss: 0.225932	valid_1's auc: 0.778931	valid_1's binary_logloss: 0.260277
# Fold 55 AUC : 0.778931
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805553	training's binary_logloss: 0.236929	valid_1's auc: 0.786733	valid_1's binary_logloss: 0.24598
# [200]	training's auc: 0.816814	training's binary_logloss: 0.23243	valid_1's auc: 0.789152	valid_1's binary_logloss: 0.24502
# Early stopping, best iteration is:
# [220]	training's auc: 0.818383	training's binary_logloss: 0.231801	valid_1's auc: 0.78986	valid_1's binary_logloss: 0.244873
# Fold 56 AUC : 0.789860
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805499	training's binary_logloss: 0.236965	valid_1's auc: 0.788491	valid_1's binary_logloss: 0.242782
# Early stopping, best iteration is:
# [144]	training's auc: 0.811296	training's binary_logloss: 0.234679	valid_1's auc: 0.790565	valid_1's binary_logloss: 0.2419
# Fold 57 AUC : 0.790565
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805571	training's binary_logloss: 0.236918	valid_1's auc: 0.805132	valid_1's binary_logloss: 0.240709
# [200]	training's auc: 0.816604	training's binary_logloss: 0.232509	valid_1's auc: 0.805917	valid_1's binary_logloss: 0.239597
# Early stopping, best iteration is:
# [201]	training's auc: 0.816751	training's binary_logloss: 0.232457	valid_1's auc: 0.806031	valid_1's binary_logloss: 0.239547
# Fold 58 AUC : 0.806031
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805618	training's binary_logloss: 0.236927	valid_1's auc: 0.810613	valid_1's binary_logloss: 0.24209
# [200]	training's auc: 0.816889	training's binary_logloss: 0.232419	valid_1's auc: 0.811655	valid_1's binary_logloss: 0.240824
# Early stopping, best iteration is:
# [194]	training's auc: 0.816158	training's binary_logloss: 0.232684	valid_1's auc: 0.811846	valid_1's binary_logloss: 0.240738
# Fold 59 AUC : 0.811846
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805567	training's binary_logloss: 0.237039	valid_1's auc: 0.81048	valid_1's binary_logloss: 0.229178
# [200]	training's auc: 0.816523	training's binary_logloss: 0.232665	valid_1's auc: 0.812551	valid_1's binary_logloss: 0.228364
# Early stopping, best iteration is:
# [221]	training's auc: 0.818264	training's binary_logloss: 0.231958	valid_1's auc: 0.813392	valid_1's binary_logloss: 0.228119
# Fold 60 AUC : 0.813392
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805547	training's binary_logloss: 0.236855	valid_1's auc: 0.789337	valid_1's binary_logloss: 0.252368
# [200]	training's auc: 0.81667	training's binary_logloss: 0.232438	valid_1's auc: 0.790507	valid_1's binary_logloss: 0.251549
# Early stopping, best iteration is:
# [207]	training's auc: 0.817284	training's binary_logloss: 0.232201	valid_1's auc: 0.791021	valid_1's binary_logloss: 0.251406
# Fold 61 AUC : 0.791021
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805192	training's binary_logloss: 0.237056	valid_1's auc: 0.802705	valid_1's binary_logloss: 0.235456
# Early stopping, best iteration is:
# [122]	training's auc: 0.808522	training's binary_logloss: 0.235776	valid_1's auc: 0.803562	valid_1's binary_logloss: 0.235014
# Fold 62 AUC : 0.803562
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805781	training's binary_logloss: 0.236683	valid_1's auc: 0.789039	valid_1's binary_logloss: 0.26541
# Early stopping, best iteration is:
# [146]	training's auc: 0.811645	training's binary_logloss: 0.234341	valid_1's auc: 0.789952	valid_1's binary_logloss: 0.264899
# Fold 63 AUC : 0.789952
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805375	training's binary_logloss: 0.236928	valid_1's auc: 0.781379	valid_1's binary_logloss: 0.249437
# Early stopping, best iteration is:
# [138]	training's auc: 0.810634	training's binary_logloss: 0.234888	valid_1's auc: 0.783241	valid_1's binary_logloss: 0.248874
# Fold 64 AUC : 0.783241
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805691	training's binary_logloss: 0.236999	valid_1's auc: 0.80769	valid_1's binary_logloss: 0.229799
# [200]	training's auc: 0.816801	training's binary_logloss: 0.232526	valid_1's auc: 0.81067	valid_1's binary_logloss: 0.228311
# [300]	training's auc: 0.825051	training's binary_logloss: 0.229166	valid_1's auc: 0.812553	valid_1's binary_logloss: 0.227531
# Early stopping, best iteration is:
# [264]	training's auc: 0.82207	training's binary_logloss: 0.230365	valid_1's auc: 0.812977	valid_1's binary_logloss: 0.227465
# Fold 65 AUC : 0.812977
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805524	training's binary_logloss: 0.236844	valid_1's auc: 0.796972	valid_1's binary_logloss: 0.252739
# [200]	training's auc: 0.81652	training's binary_logloss: 0.232447	valid_1's auc: 0.80027	valid_1's binary_logloss: 0.251616
# Early stopping, best iteration is:
# [213]	training's auc: 0.817708	training's binary_logloss: 0.231982	valid_1's auc: 0.800957	valid_1's binary_logloss: 0.251493
# Fold 66 AUC : 0.800957
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805247	training's binary_logloss: 0.237034	valid_1's auc: 0.789945	valid_1's binary_logloss: 0.244755
# [200]	training's auc: 0.816648	training's binary_logloss: 0.232531	valid_1's auc: 0.792271	valid_1's binary_logloss: 0.244039
# [300]	training's auc: 0.825022	training's binary_logloss: 0.229128	valid_1's auc: 0.795535	valid_1's binary_logloss: 0.242908
# [400]	training's auc: 0.832427	training's binary_logloss: 0.226079	valid_1's auc: 0.797657	valid_1's binary_logloss: 0.242305
# [500]	training's auc: 0.839348	training's binary_logloss: 0.223171	valid_1's auc: 0.798982	valid_1's binary_logloss: 0.242029
# Early stopping, best iteration is:
# [540]	training's auc: 0.841904	training's binary_logloss: 0.222054	valid_1's auc: 0.799424	valid_1's binary_logloss: 0.241926
# Fold 67 AUC : 0.799424
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805621	training's binary_logloss: 0.237092	valid_1's auc: 0.798225	valid_1's binary_logloss: 0.223813
# [200]	training's auc: 0.816995	training's binary_logloss: 0.232583	valid_1's auc: 0.799653	valid_1's binary_logloss: 0.223096
# Early stopping, best iteration is:
# [197]	training's auc: 0.81677	training's binary_logloss: 0.232669	valid_1's auc: 0.799975	valid_1's binary_logloss: 0.223091
# Fold 68 AUC : 0.799975
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805376	training's binary_logloss: 0.237054	valid_1's auc: 0.777456	valid_1's binary_logloss: 0.24043
# [200]	training's auc: 0.816721	training's binary_logloss: 0.232553	valid_1's auc: 0.781494	valid_1's binary_logloss: 0.239104
# [300]	training's auc: 0.82498	training's binary_logloss: 0.229168	valid_1's auc: 0.783542	valid_1's binary_logloss: 0.23871
# [400]	training's auc: 0.832468	training's binary_logloss: 0.226054	valid_1's auc: 0.785119	valid_1's binary_logloss: 0.238264
# Early stopping, best iteration is:
# [374]	training's auc: 0.830527	training's binary_logloss: 0.226856	valid_1's auc: 0.78546	valid_1's binary_logloss: 0.238073
# Fold 69 AUC : 0.785460
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805937	training's binary_logloss: 0.236978	valid_1's auc: 0.790382	valid_1's binary_logloss: 0.23173
# [200]	training's auc: 0.816913	training's binary_logloss: 0.232599	valid_1's auc: 0.792564	valid_1's binary_logloss: 0.230904
# Early stopping, best iteration is:
# [158]	training's auc: 0.812828	training's binary_logloss: 0.234212	valid_1's auc: 0.792877	valid_1's binary_logloss: 0.230912
# Fold 70 AUC : 0.792877
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805488	training's binary_logloss: 0.236896	valid_1's auc: 0.792759	valid_1's binary_logloss: 0.251003
# [200]	training's auc: 0.816596	training's binary_logloss: 0.232495	valid_1's auc: 0.797324	valid_1's binary_logloss: 0.249692
# [300]	training's auc: 0.824958	training's binary_logloss: 0.229125	valid_1's auc: 0.799861	valid_1's binary_logloss: 0.249035
# [400]	training's auc: 0.832363	training's binary_logloss: 0.226	valid_1's auc: 0.801646	valid_1's binary_logloss: 0.248468
# Early stopping, best iteration is:
# [352]	training's auc: 0.828817	training's binary_logloss: 0.227501	valid_1's auc: 0.801883	valid_1's binary_logloss: 0.248275
# Fold 71 AUC : 0.801883
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805943	training's binary_logloss: 0.236892	valid_1's auc: 0.791906	valid_1's binary_logloss: 0.238294
# Early stopping, best iteration is:
# [128]	training's auc: 0.809545	training's binary_logloss: 0.235423	valid_1's auc: 0.794076	valid_1's binary_logloss: 0.237574
# Fold 72 AUC : 0.794076
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805656	training's binary_logloss: 0.236915	valid_1's auc: 0.810979	valid_1's binary_logloss: 0.237942
# [200]	training's auc: 0.81645	training's binary_logloss: 0.232565	valid_1's auc: 0.817671	valid_1's binary_logloss: 0.235683
# [300]	training's auc: 0.824757	training's binary_logloss: 0.229201	valid_1's auc: 0.820172	valid_1's binary_logloss: 0.234728
# [400]	training's auc: 0.832182	training's binary_logloss: 0.22608	valid_1's auc: 0.822616	valid_1's binary_logloss: 0.233938
# Early stopping, best iteration is:
# [444]	training's auc: 0.834888	training's binary_logloss: 0.224904	valid_1's auc: 0.823332	valid_1's binary_logloss: 0.233715
# Fold 73 AUC : 0.823332
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.80541	training's binary_logloss: 0.237102	valid_1's auc: 0.802416	valid_1's binary_logloss: 0.229678
# [200]	training's auc: 0.81741	training's binary_logloss: 0.232405	valid_1's auc: 0.806333	valid_1's binary_logloss: 0.227997
# [300]	training's auc: 0.825754	training's binary_logloss: 0.228987	valid_1's auc: 0.807773	valid_1's binary_logloss: 0.22732
# [400]	training's auc: 0.832955	training's binary_logloss: 0.225951	valid_1's auc: 0.808105	valid_1's binary_logloss: 0.227031
# Early stopping, best iteration is:
# [364]	training's auc: 0.830443	training's binary_logloss: 0.227012	valid_1's auc: 0.808781	valid_1's binary_logloss: 0.226962
# Fold 74 AUC : 0.808781
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805738	training's binary_logloss: 0.237059	valid_1's auc: 0.79675	valid_1's binary_logloss: 0.225569
# [200]	training's auc: 0.816698	training's binary_logloss: 0.232618	valid_1's auc: 0.801626	valid_1's binary_logloss: 0.223833
# [300]	training's auc: 0.824501	training's binary_logloss: 0.229416	valid_1's auc: 0.803119	valid_1's binary_logloss: 0.223272
# [400]	training's auc: 0.832265	training's binary_logloss: 0.226279	valid_1's auc: 0.802952	valid_1's binary_logloss: 0.223189
# Early stopping, best iteration is:
# [352]	training's auc: 0.828811	training's binary_logloss: 0.227695	valid_1's auc: 0.803315	valid_1's binary_logloss: 0.223052
# Fold 75 AUC : 0.803315
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805521	training's binary_logloss: 0.236886	valid_1's auc: 0.796583	valid_1's binary_logloss: 0.247837
# [200]	training's auc: 0.816817	training's binary_logloss: 0.232422	valid_1's auc: 0.799124	valid_1's binary_logloss: 0.24673
# [300]	training's auc: 0.825301	training's binary_logloss: 0.22899	valid_1's auc: 0.799355	valid_1's binary_logloss: 0.246537
# Early stopping, best iteration is:
# [325]	training's auc: 0.827147	training's binary_logloss: 0.228238	valid_1's auc: 0.799634	valid_1's binary_logloss: 0.246373
# Fold 76 AUC : 0.799634
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805612	training's binary_logloss: 0.236965	valid_1's auc: 0.793917	valid_1's binary_logloss: 0.24035
# [200]	training's auc: 0.81704	training's binary_logloss: 0.232406	valid_1's auc: 0.797287	valid_1's binary_logloss: 0.239391
# [300]	training's auc: 0.825864	training's binary_logloss: 0.22885	valid_1's auc: 0.798338	valid_1's binary_logloss: 0.239278
# [400]	training's auc: 0.8335	training's binary_logloss: 0.225743	valid_1's auc: 0.798917	valid_1's binary_logloss: 0.23924
# Early stopping, best iteration is:
# [377]	training's auc: 0.83169	training's binary_logloss: 0.226477	valid_1's auc: 0.800022	valid_1's binary_logloss: 0.238844
# Fold 77 AUC : 0.800022
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805558	training's binary_logloss: 0.236857	valid_1's auc: 0.809776	valid_1's binary_logloss: 0.247221
# [200]	training's auc: 0.816531	training's binary_logloss: 0.232456	valid_1's auc: 0.813517	valid_1's binary_logloss: 0.245685
# [300]	training's auc: 0.824713	training's binary_logloss: 0.229113	valid_1's auc: 0.81552	valid_1's binary_logloss: 0.244802
# Early stopping, best iteration is:
# [347]	training's auc: 0.827986	training's binary_logloss: 0.227708	valid_1's auc: 0.816594	valid_1's binary_logloss: 0.244366
# Fold 78 AUC : 0.816594
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805615	training's binary_logloss: 0.236874	valid_1's auc: 0.787657	valid_1's binary_logloss: 0.24834
# [200]	training's auc: 0.816561	training's binary_logloss: 0.232489	valid_1's auc: 0.788632	valid_1's binary_logloss: 0.247911
# [300]	training's auc: 0.825027	training's binary_logloss: 0.229052	valid_1's auc: 0.790451	valid_1's binary_logloss: 0.247404
# Early stopping, best iteration is:
# [297]	training's auc: 0.824833	training's binary_logloss: 0.229138	valid_1's auc: 0.790501	valid_1's binary_logloss: 0.247383
# Fold 79 AUC : 0.790501
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805562	training's binary_logloss: 0.237125	valid_1's auc: 0.810531	valid_1's binary_logloss: 0.217962
# Early stopping, best iteration is:
# [104]	training's auc: 0.806299	training's binary_logloss: 0.236851	valid_1's auc: 0.811415	valid_1's binary_logloss: 0.217655
# Fold 80 AUC : 0.811415
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805397	training's binary_logloss: 0.236943	valid_1's auc: 0.801803	valid_1's binary_logloss: 0.244687
# [200]	training's auc: 0.816886	training's binary_logloss: 0.232412	valid_1's auc: 0.805391	valid_1's binary_logloss: 0.243189
# Early stopping, best iteration is:
# [172]	training's auc: 0.813976	training's binary_logloss: 0.233545	valid_1's auc: 0.806145	valid_1's binary_logloss: 0.243059
# Fold 81 AUC : 0.806145
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.80531	training's binary_logloss: 0.237168	valid_1's auc: 0.81034	valid_1's binary_logloss: 0.223237
# [200]	training's auc: 0.816509	training's binary_logloss: 0.232752	valid_1's auc: 0.811598	valid_1's binary_logloss: 0.222378
# Early stopping, best iteration is:
# [164]	training's auc: 0.812835	training's binary_logloss: 0.234182	valid_1's auc: 0.81228	valid_1's binary_logloss: 0.222256
# Fold 82 AUC : 0.812280
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805093	training's binary_logloss: 0.237128	valid_1's auc: 0.802836	valid_1's binary_logloss: 0.235549
# Early stopping, best iteration is:
# [113]	training's auc: 0.807227	training's binary_logloss: 0.236324	valid_1's auc: 0.803623	valid_1's binary_logloss: 0.235205
# Fold 83 AUC : 0.803623
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805503	training's binary_logloss: 0.237111	valid_1's auc: 0.77542	valid_1's binary_logloss: 0.235804
# [200]	training's auc: 0.816491	training's binary_logloss: 0.232689	valid_1's auc: 0.780718	valid_1's binary_logloss: 0.234613
# [300]	training's auc: 0.824424	training's binary_logloss: 0.229433	valid_1's auc: 0.783299	valid_1's binary_logloss: 0.233549
# Early stopping, best iteration is:
# [289]	training's auc: 0.823642	training's binary_logloss: 0.229754	valid_1's auc: 0.78379	valid_1's binary_logloss: 0.233414
# Fold 84 AUC : 0.783790
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805335	training's binary_logloss: 0.236875	valid_1's auc: 0.793899	valid_1's binary_logloss: 0.253573
# [200]	training's auc: 0.816639	training's binary_logloss: 0.232387	valid_1's auc: 0.797702	valid_1's binary_logloss: 0.252101
# [300]	training's auc: 0.825119	training's binary_logloss: 0.22897	valid_1's auc: 0.799533	valid_1's binary_logloss: 0.251474
# Early stopping, best iteration is:
# [294]	training's auc: 0.824768	training's binary_logloss: 0.229116	valid_1's auc: 0.799959	valid_1's binary_logloss: 0.25131
# Fold 85 AUC : 0.799959
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805618	training's binary_logloss: 0.236937	valid_1's auc: 0.764359	valid_1's binary_logloss: 0.248144
# [200]	training's auc: 0.817135	training's binary_logloss: 0.232393	valid_1's auc: 0.769892	valid_1's binary_logloss: 0.246759
# [300]	training's auc: 0.825421	training's binary_logloss: 0.229046	valid_1's auc: 0.771753	valid_1's binary_logloss: 0.246286
# Early stopping, best iteration is:
# [274]	training's auc: 0.823225	training's binary_logloss: 0.229927	valid_1's auc: 0.772131	valid_1's binary_logloss: 0.246068
# Fold 86 AUC : 0.772131
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.789016	training's binary_logloss: 0.247499	valid_1's auc: 0.796329	valid_1's binary_logloss: 0.229673
# Fold 87 AUC : 0.796329
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805647	training's binary_logloss: 0.236841	valid_1's auc: 0.795345	valid_1's binary_logloss: 0.247991
# [200]	training's auc: 0.816853	training's binary_logloss: 0.232379	valid_1's auc: 0.797561	valid_1's binary_logloss: 0.246992
# Early stopping, best iteration is:
# [223]	training's auc: 0.819105	training's binary_logloss: 0.231456	valid_1's auc: 0.79807	valid_1's binary_logloss: 0.246811
# Fold 88 AUC : 0.798070
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805636	training's binary_logloss: 0.236987	valid_1's auc: 0.786257	valid_1's binary_logloss: 0.23759
# [200]	training's auc: 0.816975	training's binary_logloss: 0.232442	valid_1's auc: 0.788812	valid_1's binary_logloss: 0.236906
# Early stopping, best iteration is:
# [152]	training's auc: 0.812117	training's binary_logloss: 0.234398	valid_1's auc: 0.788955	valid_1's binary_logloss: 0.236712
# Fold 89 AUC : 0.788955
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805902	training's binary_logloss: 0.236967	valid_1's auc: 0.768702	valid_1's binary_logloss: 0.236207
# [200]	training's auc: 0.816853	training's binary_logloss: 0.232601	valid_1's auc: 0.772186	valid_1's binary_logloss: 0.235666
# Early stopping, best iteration is:
# [246]	training's auc: 0.820874	training's binary_logloss: 0.230969	valid_1's auc: 0.772751	valid_1's binary_logloss: 0.235518
# Fold 90 AUC : 0.772751
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805712	training's binary_logloss: 0.23694	valid_1's auc: 0.774199	valid_1's binary_logloss: 0.241702
# [200]	training's auc: 0.817116	training's binary_logloss: 0.232417	valid_1's auc: 0.77602	valid_1's binary_logloss: 0.241748
# Early stopping, best iteration is:
# [154]	training's auc: 0.812662	training's binary_logloss: 0.234166	valid_1's auc: 0.77568	valid_1's binary_logloss: 0.24156
# Fold 91 AUC : 0.775680
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805193	training's binary_logloss: 0.237117	valid_1's auc: 0.807077	valid_1's binary_logloss: 0.235707
# [200]	training's auc: 0.816437	training's binary_logloss: 0.232621	valid_1's auc: 0.812177	valid_1's binary_logloss: 0.233685
# [300]	training's auc: 0.824571	training's binary_logloss: 0.229316	valid_1's auc: 0.81298	valid_1's binary_logloss: 0.232878
# Early stopping, best iteration is:
# [281]	training's auc: 0.823184	training's binary_logloss: 0.229892	valid_1's auc: 0.813484	valid_1's binary_logloss: 0.232783
# Fold 92 AUC : 0.813484
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805416	training's binary_logloss: 0.237059	valid_1's auc: 0.809724	valid_1's binary_logloss: 0.231861
# [200]	training's auc: 0.816849	training's binary_logloss: 0.23254	valid_1's auc: 0.813086	valid_1's binary_logloss: 0.230477
# [300]	training's auc: 0.825649	training's binary_logloss: 0.228985	valid_1's auc: 0.814632	valid_1's binary_logloss: 0.23005
# [400]	training's auc: 0.83308	training's binary_logloss: 0.225879	valid_1's auc: 0.816003	valid_1's binary_logloss: 0.229785
# Early stopping, best iteration is:
# [408]	training's auc: 0.833841	training's binary_logloss: 0.225563	valid_1's auc: 0.81633	valid_1's binary_logloss: 0.229702
# Fold 93 AUC : 0.816330
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805596	training's binary_logloss: 0.237016	valid_1's auc: 0.794485	valid_1's binary_logloss: 0.232495
# [200]	training's auc: 0.816868	training's binary_logloss: 0.23255	valid_1's auc: 0.797325	valid_1's binary_logloss: 0.23117
# [300]	training's auc: 0.825264	training's binary_logloss: 0.229125	valid_1's auc: 0.798138	valid_1's binary_logloss: 0.230891
# Early stopping, best iteration is:
# [281]	training's auc: 0.823785	training's binary_logloss: 0.229769	valid_1's auc: 0.798351	valid_1's binary_logloss: 0.230684
# Fold 94 AUC : 0.798351
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805349	training's binary_logloss: 0.23695	valid_1's auc: 0.79999	valid_1's binary_logloss: 0.246555
# [200]	training's auc: 0.816483	training's binary_logloss: 0.232486	valid_1's auc: 0.800548	valid_1's binary_logloss: 0.245944
# Early stopping, best iteration is:
# [186]	training's auc: 0.815222	training's binary_logloss: 0.233	valid_1's auc: 0.801274	valid_1's binary_logloss: 0.245826
# Fold 95 AUC : 0.801274
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805538	training's binary_logloss: 0.236856	valid_1's auc: 0.782556	valid_1's binary_logloss: 0.253658
# [200]	training's auc: 0.817094	training's binary_logloss: 0.232273	valid_1's auc: 0.786903	valid_1's binary_logloss: 0.252733
# [300]	training's auc: 0.825407	training's binary_logloss: 0.228957	valid_1's auc: 0.789098	valid_1's binary_logloss: 0.252067
# [400]	training's auc: 0.832316	training's binary_logloss: 0.225993	valid_1's auc: 0.790513	valid_1's binary_logloss: 0.25163
# Early stopping, best iteration is:
# [376]	training's auc: 0.830724	training's binary_logloss: 0.226675	valid_1's auc: 0.790884	valid_1's binary_logloss: 0.251558
# Fold 96 AUC : 0.790884
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805715	training's binary_logloss: 0.236938	valid_1's auc: 0.797842	valid_1's binary_logloss: 0.236346
# [200]	training's auc: 0.816969	training's binary_logloss: 0.232446	valid_1's auc: 0.800064	valid_1's binary_logloss: 0.23521
# Early stopping, best iteration is:
# [202]	training's auc: 0.817157	training's binary_logloss: 0.232368	valid_1's auc: 0.800335	valid_1's binary_logloss: 0.235124
# Fold 97 AUC : 0.800335
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805546	training's binary_logloss: 0.236919	valid_1's auc: 0.802276	valid_1's binary_logloss: 0.239742
# [200]	training's auc: 0.816843	training's binary_logloss: 0.232442	valid_1's auc: 0.802756	valid_1's binary_logloss: 0.238723
# [300]	training's auc: 0.825563	training's binary_logloss: 0.228915	valid_1's auc: 0.803239	valid_1's binary_logloss: 0.238335
# Early stopping, best iteration is:
# [281]	training's auc: 0.823936	training's binary_logloss: 0.229549	valid_1's auc: 0.803763	valid_1's binary_logloss: 0.238247
# Fold 98 AUC : 0.803763
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805721	training's binary_logloss: 0.237	valid_1's auc: 0.794533	valid_1's binary_logloss: 0.232226
# [200]	training's auc: 0.816751	training's binary_logloss: 0.23259	valid_1's auc: 0.798896	valid_1's binary_logloss: 0.230772
# [300]	training's auc: 0.824952	training's binary_logloss: 0.229252	valid_1's auc: 0.801488	valid_1's binary_logloss: 0.22996
# [400]	training's auc: 0.831906	training's binary_logloss: 0.226308	valid_1's auc: 0.803848	valid_1's binary_logloss: 0.229136
# Early stopping, best iteration is:
# [436]	training's auc: 0.834175	training's binary_logloss: 0.225349	valid_1's auc: 0.804063	valid_1's binary_logloss: 0.229065
# Fold 99 AUC : 0.804063
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.805493	training's binary_logloss: 0.237029	valid_1's auc: 0.81636	valid_1's binary_logloss: 0.232629
# Early stopping, best iteration is:
# [103]	training's auc: 0.80601	training's binary_logloss: 0.236828	valid_1's auc: 0.816662	valid_1's binary_logloss: 0.232463
# Fold 100 AUC : 0.816662
# Full AUC score 0.800164

# %%
test_preds.rename({'loan_id': 'id'}, axis=1)[['id', 'isDefault']].to_csv('./submit/test1.csv', index=False)

# %%
test_preds
# Out:
#        loan_id  isDefault
# 10000  1000575   0.007524
# 10001  1028125   0.049944
# 10002  1010694   0.002732
# 10003  1026712   0.004698
# 10004  1002895   0.004800
# ...        ...        ...
# 14995  1008856   0.467859
# 14996  1016651   0.012328
# 14997  1024140   0.001804
# 14998  1014316   0.003937
# 14999  1012946   0.002805
#
# [5000 rows x 2 columns]

# %%
tmp = test_preds['isDefault']
c = np.sum(tmp>1)
c
# Out:
# 0
