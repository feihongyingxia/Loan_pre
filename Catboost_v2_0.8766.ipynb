# %%
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import gc
from sklearn.model_selection import StratifiedKFold
import category_encoders

# %%
train_data = pd.read_csv('./train_dataset/train_public.csv')
test_public = pd.read_csv('./test_public.csv')
train_internet = pd.read_csv('./train_dataset/train_internet.csv')

# %%
train_data.shape
# Out:
# (10000, 39)

# %%
X_train = train_data.copy()
X_test = test_public.copy()

# %%
X_train = X_train.drop(['isDefault'], axis = 1)
X_train.shape
# Out:
# (10000, 38)

# %%
X_train['is_train'] = 1
X_test['is_train'] = 0

X_traintest = X_traintest = pd.concat([X_train, X_test], axis = 0)
X_traintest.shape
# Out:
# (15000, 39)

# %% [markdown]
# ### 数据探索

# %%
X_traintest.head(39)
# Out:
#     loan_id  user_id    total_loan  year_of_loan  interest  monthly_payment  \
# 0   1040418   240418  31818.181820             3    11.466          1174.91
# 1   1025197   225197  28000.000000             5    16.841           670.69
# 2   1009360   209360  17272.727270             3     8.900           603.32
# 3   1039708   239708  20000.000000             3     4.788           602.30
# 4   1027483   227483  15272.727270             3    12.790           470.31
# 5   1047529   247529  25454.545450             3    10.637           899.15
# 6   1030964   230964   9090.909091             5    15.741           234.30
# 7   1024822   224822  10288.636360             3    11.490           414.62
# 8   1008720   208720   6818.181818             3    20.064           272.05
# 9   1045305   245305  10800.000000             3    14.330           339.95
# 10  1007760   207760  14727.272730             5    12.897           421.92
# 11  1042906   242906   6400.000000             3    20.889           234.57
# 12  1047890   247890  29454.545450             3     6.489          1115.04
# 13  1049951   249951   1636.363636             3    17.091            65.98
# 14  1043543   243543  20415.909090             5    15.291           429.24
# 15  1020746   220746   5500.000000             3    12.620           184.32
# 16  1010877   210877  35000.000000             5    12.690           790.82
# 17  1015159   215159   7090.909091             3     6.615           186.23
# 18  1001504   201504  20454.545450             3     6.291           771.82
# 19  1020141   220141   8181.818182             5    17.171           241.12
# 20  1033907   233907  41363.636360             5    15.939           823.31
# 21  1008326   208326   8727.272727             3    10.923           257.88
# 22  1038312   238312  16363.636360             5    14.193           483.93
# 23  1022595   222595  21818.181820             3     9.990           645.25
# 24  1013319   213319   4545.454545             3    12.744           171.28
# 25  1033417   233417  17727.272730             3    17.091           549.77
# 26  1037240   237240  18590.909090             5    19.990           541.69
# 27  1008433   208433   3636.363636             3    13.185           137.98
# 28  1029038   229038  27409.090910             5    12.591           779.32
# 29  1023768   223768   3220.454545             3    10.791            90.50
# 30  1025265   225265  30000.000000             3     5.841           903.31
# 31  1044891   244891  24818.181820             3    14.391           738.20
# 32  1000808   200808  35454.545450             5    13.490           690.15
# 33  1011649   211649   8727.272727             3    10.076           255.00
# 34  1023458   223458   8181.818182             3     8.239           311.02
# 35  1021556   221556  15709.090910             3    11.691           646.84
# 36  1031304   231304  22909.090910             5    17.171           506.34
# 37  1009118   209118  28363.636360             5    19.327           603.85
# 38  1032230   232230  27272.727270             3    12.880           840.91
#
#    class employer_type         industry  work_year  ...  policy_code    f0  \
# 0      C          政府机构              金融业    3 years  ...            1   1.0
# 1      C          政府机构              金融业  10+ years  ...            1   7.0
# 2      A          政府机构        公共服务、社会组织  10+ years  ...            1   6.0
# 3      A         世界五百强           文化和体育业    6 years  ...            1   5.0
# 4      C          政府机构  信息传输、软件和信息技术服务业   < 1 year  ...            1  10.0
# 5      B       幼教与中小学校  信息传输、软件和信息技术服务业  10+ years  ...            1   6.0
# 6      C        高等教育机构              金融业  10+ years  ...            1   4.0
# 7      B          普通企业              制造业    2 years  ...            1   4.0
# 8      D          普通企业              金融业        NaN  ...            1   6.0
# 9      C       幼教与中小学校           住宿和餐饮业    4 years  ...            1   3.0
# 10     C          政府机构              建筑业    3 years  ...            1   4.0
# 11     E       幼教与中小学校              金融业        NaN  ...            1   3.0
# 12     A          政府机构       电力、热力生产供应业   < 1 year  ...            1   8.0
# 13     D          普通企业           住宿和餐饮业  10+ years  ...            1   3.0
# 14     D          普通企业       电力、热力生产供应业  10+ years  ...            1   3.0
# 15     C          普通企业           住宿和餐饮业        NaN  ...            1   4.0
# 16     C          上市企业              建筑业    3 years  ...            1   3.0
# 17     A          普通企业              金融业    3 years  ...            1   8.0
# 18     A          普通企业        公共服务、社会组织     1 year  ...            1   8.0
# 19     D          普通企业              金融业  10+ years  ...            1   4.0
# 20     C          普通企业       电力、热力生产供应业  10+ years  ...            1  14.0
# 21     B          政府机构              金融业    2 years  ...            1   4.0
# 22     D          上市企业           文化和体育业    4 years  ...            1   4.0
# 23     B          普通企业        公共服务、社会组织    8 years  ...            1   2.0
# 24     C          普通企业             房地产业    4 years  ...            1   2.0
# 25     D        高等教育机构  信息传输、软件和信息技术服务业   < 1 year  ...            1   3.0
# 26     E          普通企业              建筑业    5 years  ...            1   4.0
# 27     C          普通企业      交通运输、仓储和邮政业  10+ years  ...            1   9.0
# 28     C         世界五百强           批发和零售业  10+ years  ...            1   3.0
# 29     B          普通企业  信息传输、软件和信息技术服务业    3 years  ...            1   5.0
# 30     A       幼教与中小学校              建筑业  10+ years  ...            1   6.0
# 31     C          普通企业             房地产业  10+ years  ...            1   8.0
# 32     C          政府机构           文化和体育业    8 years  ...            1   5.0
# 33     B          普通企业              金融业  10+ years  ...            1  12.0
# 34     A         世界五百强      交通运输、仓储和邮政业  10+ years  ...            1   5.0
# 35     C          政府机构       电力、热力生产供应业    4 years  ...            1   3.0
# 36     D          上市企业           文化和体育业  10+ years  ...            1   1.0
# 37     D          普通企业           批发和零售业   < 1 year  ...            1   6.0
# 38     C        高等教育机构  信息传输、软件和信息技术服务业  10+ years  ...            1   4.0
#
#      f1    f2    f3    f4  early_return  early_return_amount  \
# 0   0.0   4.0   5.0   4.0             3                 9927
# 1   0.0   4.0  45.0  22.0             0                    0
# 2   0.0   6.0  28.0  19.0             0                    0
# 3   0.0  10.0  15.0   9.0             0                    0
# 4   0.0   6.0  15.0   4.0             0                    0
# 5   0.0   6.0  20.0  15.0             0                    0
# 6   0.0   9.0  25.0   6.0             0                    0
# 7   0.0   0.0   9.0   9.0             0                    0
# 8   0.0   2.0  34.0  22.0             0                    0
# 9   0.0  15.0   6.0   6.0             0                    0
# 10  0.0   8.0  11.0   9.0             0                    0
# 11  0.0   6.0  16.0   9.0             0                    0
# 12  0.0  24.0  30.0  10.0             0                    0
# 13  0.0   6.0   4.0   2.0             0                    0
# 14  0.0  10.0   9.0   6.0             0                    0
# 15  0.0   6.0   9.0   4.0             0                    0
# 16  0.0  10.0  18.0   6.0             0                    0
# 17  0.0   4.0  14.0   6.0             0                    0
# 18  0.0   2.0  19.0  12.0             0                    0
# 19  0.0   5.0   6.0   4.0             0                    0
# 20  0.0  14.0  24.0  11.0             0                    0
# 21  0.0   1.0   5.0   3.0             0                    0
# 22  0.0  12.0   7.0   3.0             0                    0
# 23  0.0   3.0  17.0  12.0             0                    0
# 24  0.0   1.0   4.0   3.0             0                    0
# 25  0.0   5.0   4.0   3.0             0                    0
# 26  0.0   9.0   8.0   1.0             0                    0
# 27  0.0   5.0  13.0  11.0             0                    0
# 28  0.0   5.0   4.0   3.0             0                    0
# 29  0.0  12.0  20.0  12.0             0                    0
# 30  0.0   9.0  10.0   6.0             0                    0
# 31  0.0   5.0  30.0   9.0             0                    0
# 32  0.0   6.0   8.0   6.0             0                    0
# 33  NaN  12.0  16.0   8.0             0                    0
# 34  0.0  10.0  11.0   8.0             3                  341
# 35  0.0   6.0  10.0   4.0             3                 4587
# 36  0.0   2.0   2.0   0.0             0                 5417
# 37  0.0   5.0  13.0   4.0             5                 9268
# 38  0.0   3.0   6.0   2.0             0                10584
#
#     early_return_amount_3mon  is_train
# 0                        0.0         1
# 1                        0.0         1
# 2                        0.0         1
# 3                        0.0         1
# 4                        0.0         1
# 5                        0.0         1
# 6                        0.0         1
# 7                        0.0         1
# 8                        0.0         1
# 9                        0.0         1
# 10                       0.0         1
# 11                       0.0         1
# 12                       0.0         1
# 13                       0.0         1
# 14                       0.0         1
# 15                       0.0         1
# 16                       0.0         1
# 17                       0.0         1
# 18                       0.0         1
# 19                       0.0         1
# 20                       0.0         1
# 21                       0.0         1
# 22                       0.0         1
# 23                       0.0         1
# 24                       0.0         1
# 25                       0.0         1
# 26                       0.0         1
# 27                       0.0         1
# 28                       0.0         1
# 29                       0.0         1
# 30                       0.0         1
# 31                       0.0         1
# 32                       0.0         1
# 33                       0.0         1
# 34                      68.2         1
# 35                     917.4         1
# 36                    1083.4         1
# 37                     926.8         1
# 38                    2116.8         1
#
# [39 rows x 39 columns]

# %%
X_traintest.columns
# Out:
# Index(['loan_id', 'user_id', 'total_loan', 'year_of_loan', 'interest',
#        'monthly_payment', 'class', 'employer_type', 'industry', 'work_year',
#        'house_exist', 'censor_status', 'issue_date', 'use', 'post_code',
#        'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low',
#        'scoring_high', 'known_outstanding_loan', 'known_dero',
#        'pub_dero_bankrup', 'recircle_b', 'recircle_u', 'initial_list_status',
#        'app_type', 'earlies_credit_mon', 'title', 'policy_code', 'f0', 'f1',
#        'f2', 'f3', 'f4', 'early_return', 'early_return_amount',
#        'early_return_amount_3mon', 'is_train'],
#       dtype='object')

# %%
X_traintest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 0 to 4999
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   15000 non-null  int64
#  1   user_id                   15000 non-null  int64
#  2   total_loan                15000 non-null  float64
#  3   year_of_loan              15000 non-null  int64
#  4   interest                  15000 non-null  float64
#  5   monthly_payment           15000 non-null  float64
#  6   class                     15000 non-null  object
#  7   employer_type             15000 non-null  object
#  8   industry                  15000 non-null  object
#  9   work_year                 14100 non-null  object
#  10  house_exist               15000 non-null  int64
#  11  censor_status             15000 non-null  int64
#  12  issue_date                15000 non-null  object
#  13  use                       15000 non-null  int64
#  14  post_code                 15000 non-null  int64
#  15  region                    15000 non-null  int64
#  16  debt_loan_ratio           15000 non-null  float64
#  17  del_in_18month            15000 non-null  int64
#  18  scoring_low               15000 non-null  float64
#  19  scoring_high              15000 non-null  float64
#  20  known_outstanding_loan    15000 non-null  int64
#  21  known_dero                15000 non-null  int64
#  22  pub_dero_bankrup          14989 non-null  float64
#  23  recircle_b                15000 non-null  float64
#  24  recircle_u                15000 non-null  float64
#  25  initial_list_status       15000 non-null  int64
#  26  app_type                  15000 non-null  int64
#  27  earlies_credit_mon        15000 non-null  object
#  28  title                     15000 non-null  int64
#  29  policy_code               15000 non-null  int64
#  30  f0                        14243 non-null  float64
#  31  f1                        13688 non-null  float64
#  32  f2                        14243 non-null  float64
#  33  f3                        14243 non-null  float64
#  34  f4                        14243 non-null  float64
#  35  early_return              15000 non-null  int64
#  36  early_return_amount       15000 non-null  int64
#  37  early_return_amount_3mon  15000 non-null  float64
#  38  is_train                  15000 non-null  int64
# dtypes: float64(15), int64(18), object(6)
# memory usage: 4.6+ MB

# %%
print(f'There are {X_traintest.isnull().any().sum()} columns in train dataset with missing values.')
# Out:
# There are 7 columns in train dataset with missing values.

# %%
have_null_fea_dict = (X_traintest.isnull().sum()/len(X_traintest)).to_dict() 
fea_null_moreThanThreshold = {} 
for key,value in have_null_fea_dict.items(): 
    if value > 0.4: 
        fea_null_moreThanThreshold[key] = value
fea_null_moreThanThreshold
# Out:
# {}

# %%
missing = X_traintest.isnull().sum()/len(X_traintest) 
missing = missing[missing > 0] 
missing.sort_values(inplace=True) 
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %%
one_value_fea = [col for col in X_traintest.columns if X_traintest[col].nunique() <= 1]
print(one_value_fea)
print(f'There are {len(one_value_fea)} columns in train dataset with one unique value.')
# Out:
# ['policy_code']
# There are 1 columns in train dataset with one unique value.

# %%
X_traintest = X_traintest.drop('loan_id', axis=1)

X_traintest = X_traintest.drop('user_id', axis=1)

X_traintest = X_traintest.drop(one_value_fea, axis=1)

# %%
numerical_fea = list(X_traintest.select_dtypes(exclude=['object']).columns) 
category_fea = list(filter(lambda x: x not in numerical_fea,list(X_traintest.columns)))
print("numerical_fea:",numerical_fea)
print("category_fea:",category_fea)
# Out:
# numerical_fea: ['total_loan', 'year_of_loan', 'interest', 'monthly_payment', 'house_exist', 'censor_status', 'use', 'post_code', 'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low', 'scoring_high', 'known_outstanding_loan', 'known_dero', 'pub_dero_bankrup', 'recircle_b', 'recircle_u', 'initial_list_status', 'app_type', 'title', 'f0', 'f1', 'f2', 'f3', 'f4', 'early_return', 'early_return_amount', 'early_return_amount_3mon', 'is_train']
# category_fea: ['class', 'employer_type', 'industry', 'work_year', 'issue_date', 'earlies_credit_mon']

# %%
def get_numerical_serial_fea(data,feas): 
    numerical_serial_fea = [] 
    numerical_noserial_fea = [] 
    for fea in feas: 
        temp = data[fea].nunique() 
        if temp <= 10: 
            numerical_noserial_fea.append(fea) 
            continue 
        numerical_serial_fea.append(fea) 
    return numerical_serial_fea,numerical_noserial_fea 
numerical_serial_fea,numerical_noserial_fea = get_numerical_serial_fea(X_traintest,numerical_fea)
print("numerical_fea中的numerical_serial_fea:",numerical_serial_fea)
print("numerical_fea中的numerical_noserial_fea:",numerical_noserial_fea)
# Out:
# numerical_fea中的numerical_serial_fea: ['total_loan', 'interest', 'monthly_payment', 'use', 'post_code', 'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low', 'scoring_high', 'known_outstanding_loan', 'known_dero', 'recircle_b', 'recircle_u', 'title', 'f0', 'f2', 'f3', 'f4', 'early_return_amount', 'early_return_amount_3mon']
# numerical_fea中的numerical_noserial_fea: ['year_of_loan', 'house_exist', 'censor_status', 'pub_dero_bankrup', 'initial_list_status', 'app_type', 'f1', 'early_return', 'is_train']

# %% [markdown]
# ### 特征工程

# %% [markdown]
# #### work_year, class

# %%
work_year_dict = {
    '< 1 year': 0,
    '1 year': 1,
    '2 years': 2,
    '3 years': 3,
    '4 years': 4,
    '5 years': 5,
    '6 years': 6,
    '7 years': 7,
    '8 years': 8,
    '9 years': 9,
    '10+ years': 10,
}

# train_data['work_year'] = train_data['work_year'].map(work_year_dict)
# test_public['work_year'] = test_public['work_year'].map(work_year_dict)
# train_data['work_year'] = train_data['work_year'].fillna(-1)
# test_public['work_year'] = test_public['work_year'].fillna(-1)
# train_internet['work_year'] = train_internet['work_year'].map(work_year_dict)
# train_internet['work_year'] = train_internet['work_year'].fillna(-1)

X_traintest['num_work_year'] = X_traintest['work_year'].map(work_year_dict)

# %%
class_dict = {
    'A': 1,
    'B': 2,
    'C': 3,
    'D': 4,
    'E': 5,
    'F': 6,
    'G': 7,
}

# train_data['class'] = train_data['class'].map(class_dict)
# test_public['class'] = test_public['class'].map(class_dict)
# train_internet['class'] = train_internet['class'].map(class_dict)

X_traintest['num_class'] = X_traintest['class'].map(class_dict)

# %% [markdown]
# #### issue_date, earlies_credit_mon

# %%
# train_data['issue_date'] = pd.to_datetime(train_data['issue_date'])
# test_public['issue_date'] = pd.to_datetime(test_public['issue_date'])
# train_internet['issue_date'] = pd.to_datetime(train_internet['issue_date'])

# train_data['issue_date_month'] = train_data['issue_date'].dt.month
# test_public['issue_date_month'] = train_data['issue_date'].dt.month
# train_internet['issue_date_month'] = train_internet['issue_date'].dt.month

# train_data['issue_date_dayofweek'] = train_data['issue_date'].dt.dayofweek
# test_public['issue_date_dayofweek'] = train_data['issue_date'].dt.dayofweek
# train_internet['issue_date_dayofweek'] = train_internet['issue_date'].dt.dayofweek

X_traintest['issue_date'] = pd.to_datetime(X_traintest['issue_date'])

X_traintest['issue_date_month'] = X_traintest['issue_date'].dt.month

X_traintest['issue_date_dayofweek'] = X_traintest['issue_date'].dt.dayofweek

X_traintest['issue_date_delta'] = (X_traintest['issue_date'] - X_traintest['issue_date'].min())  / np.timedelta64(1,'D')

# %%
X_traintest['earlies_credit_mon'] = pd.to_datetime(X_traintest['earlies_credit_mon'])

X_traintest['earlies_credit_mon_delta'] = (X_traintest['earlies_credit_mon'] - X_traintest['earlies_credit_mon'].min())  / np.timedelta64(1,'D')

# %%
X_traintest['earlies_credit_Mon'] = X_traintest['earlies_credit_mon'].dt.month

X_traintest['earlies_credit_Year'] = X_traintest['earlies_credit_mon'].dt.year

X_traintest['earlies_credit_dayofweek'] = X_traintest['earlies_credit_mon'].dt.dayofweek

# %%
X_traintest['earlies_credit_Mon']
# Out:
# 0       12
# 1        4
# 2       10
# 3        6
# 4        5
#         ..
# 4995     7
# 4996     4
# 4997    10
# 4998     3
# 4999     7
# Name: earlies_credit_Mon, Length: 15000, dtype: int64

# %% [markdown]
# #### employer_type, industry

# %%
from sklearn.preprocessing import LabelEncoder


lbl1 = LabelEncoder().fit(X_traintest['employer_type'])
X_traintest['num_employer_type'] = lbl1.transform(X_traintest['employer_type'])

lbl2 = LabelEncoder().fit(X_traintest['industry'])
X_traintest['num_industry'] = lbl2.transform(X_traintest['industry'])

# %%
X_traintest['num_industry']
# Out:
# 0       13
# 1       13
# 2        3
# 3       10
# 4        2
#         ..
# 4995     2
# 4996     8
# 4997     8
# 4998    10
# 4999     0
# Name: num_industry, Length: 15000, dtype: int32

# %% [markdown]
# #### Internet表补充

# %%
# tr_cols = set(train_data.columns)
# same_col = list(tr_cols.intersection(set(train_internet.columns)))
# train_inteSame = train_internet[same_col].copy()

# Inte_add_cos = list(tr_cols.difference(set(same_col)))
# for col in Inte_add_cos:
#     train_inteSame[col] = np.nan

# %% [markdown]
# #### Counts

# %%
X_traintest['house_exist']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       2
#        ..
# 4995    1
# 4996    1
# 4997    0
# 4998    0
# 4999    1
# Name: house_exist, Length: 15000, dtype: int64

# %%
X_traintest['house_exist_cnt'] = category_encoders.count.CountEncoder().fit_transform(X_traintest['house_exist'])

X_traintest['employer_type_cnt'] = category_encoders.count.CountEncoder().fit_transform(X_traintest['employer_type'])

X_traintest['work_year_cnt'] = category_encoders.count.CountEncoder().fit_transform(X_traintest['work_year'])

X_traintest['industry_cnt'] = category_encoders.count.CountEncoder().fit_transform(X_traintest['industry'])

# %% [markdown]
# #### 数值型特征，分类型特征

# %%
numerical_fea = list(X_traintest.select_dtypes(exclude=['object']).columns) 
category_fea = list(filter(lambda x: x not in numerical_fea,list(X_traintest.columns)))
print("numerical_fea:",numerical_fea)
print("category_fea:",category_fea)
# Out:
# numerical_fea: ['total_loan', 'year_of_loan', 'interest', 'monthly_payment', 'house_exist', 'censor_status', 'issue_date', 'use', 'post_code', 'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low', 'scoring_high', 'known_outstanding_loan', 'known_dero', 'pub_dero_bankrup', 'recircle_b', 'recircle_u', 'initial_list_status', 'app_type', 'earlies_credit_mon', 'title', 'f0', 'f1', 'f2', 'f3', 'f4', 'early_return', 'early_return_amount', 'early_return_amount_3mon', 'is_train', 'num_work_year', 'num_class', 'issue_date_month', 'issue_date_dayofweek', 'issue_date_delta', 'earlies_credit_mon_delta', 'earlies_credit_Mon', 'earlies_credit_Year', 'earlies_credit_dayofweek', 'num_employer_type', 'num_industry', 'house_exist_cnt', 'employer_type_cnt', 'work_year_cnt', 'industry_cnt']
# category_fea: ['class', 'employer_type', 'industry', 'work_year']

# %%
numerical_fea.remove('issue_date')
numerical_fea.remove('earlies_credit_mon')

category_fea.append('issue_date')
category_fea.append('earlies_credit_mon')

# %%
print("numerical_fea:",numerical_fea)
print("category_fea:",category_fea)
# Out:
# numerical_fea: ['total_loan', 'year_of_loan', 'interest', 'monthly_payment', 'house_exist', 'censor_status', 'use', 'post_code', 'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low', 'scoring_high', 'known_outstanding_loan', 'known_dero', 'pub_dero_bankrup', 'recircle_b', 'recircle_u', 'initial_list_status', 'app_type', 'title', 'f0', 'f1', 'f2', 'f3', 'f4', 'early_return', 'early_return_amount', 'early_return_amount_3mon', 'is_train', 'num_work_year', 'num_class', 'issue_date_month', 'issue_date_dayofweek', 'issue_date_delta', 'earlies_credit_mon_delta', 'earlies_credit_Mon', 'earlies_credit_Year', 'earlies_credit_dayofweek', 'num_employer_type', 'num_industry', 'house_exist_cnt', 'employer_type_cnt', 'work_year_cnt', 'industry_cnt']
# category_fea: ['class', 'employer_type', 'industry', 'work_year', 'issue_date', 'earlies_credit_mon']

# %% [markdown]
# ### 模型

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import catboost

# %%
all_fea = X_traintest.columns

# %%
X_train = X_traintest[X_traintest.is_train == 1][all_fea]
y_train = train_data['isDefault']

X_test = X_traintest[X_traintest.is_train == 0][all_fea]

# %%
X_train[category_fea] = X_train[category_fea].astype(str)
X_test[category_fea] = X_test[category_fea].astype(str)

X_train[numerical_fea] = X_train[numerical_fea].astype(float)
X_test[numerical_fea] = X_test[numerical_fea].astype(float)

# %%
model = catboost.CatBoostClassifier(cat_features = category_fea, random_state = 2080)
model.fit(X_train, y_train, verbose=400)
# Out:
# Learning rate set to 0.027538
# 0:	learn: 0.6619150	total: 241ms	remaining: 4m
# 400:	learn: 0.2547734	total: 10.8s	remaining: 16.2s
# 800:	learn: 0.2105497	total: 22s	remaining: 5.46s
# 999:	learn: 0.1935721	total: 27.8s	remaining: 0us

# %%
y_pred = model.predict_proba(X_test)

# %%
submission = pd.read_csv('./submit_example.csv')
submission['isDefault'] =1-y_pred
submission.to_csv('./submit/catboost_v2.csv')

# %%
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

# %%
feature_importances = model.get_feature_importance(prettified=True,
                                                   thread_count=-1,
                                                   verbose=False)

# %%
print(feature_importances)
# Out:
#                   Feature Id  Importances
# 0        early_return_amount    27.689448
# 1     known_outstanding_loan     5.999463
# 2            debt_loan_ratio     3.412294
# 3               early_return     3.161607
# 4            monthly_payment     2.994201
# 5                 recircle_b     2.885601
# 6               scoring_high     2.695921
# 7                 issue_date     2.663620
# 8                         f2     2.639868
# 9                      class     2.604372
# 10        earlies_credit_mon     2.381961
# 11  earlies_credit_mon_delta     2.261330
# 12                  interest     2.211311
# 13                 post_code     2.050782
# 14                recircle_u     2.013807
# 15          issue_date_delta     1.855074
# 16  early_return_amount_3mon     1.779525
# 17                        f3     1.604967
# 18                total_loan     1.572286
# 19  earlies_credit_dayofweek     1.533656
# 20                 work_year     1.480764
# 21                        f0     1.478676
# 22                        f4     1.442052
# 23          issue_date_month     1.412387
# 24                known_dero     1.359264
# 25                  industry     1.321334
# 26        earlies_credit_Mon     1.293854
# 27               scoring_low     1.198084
# 28             employer_type     1.064589
# 29      issue_date_dayofweek     1.050648
# 30                    region     1.028248
# 31                     title     0.929735
# 32              num_industry     0.912594
# 33           house_exist_cnt     0.857746
# 34             work_year_cnt     0.797966
# 35               house_exist     0.760582
# 36             num_work_year     0.757763
# 37                       use     0.696077
# 38              year_of_loan     0.686276
# 39                 num_class     0.575827
# 40             censor_status     0.561858
# 41       earlies_credit_Year     0.506644
# 42              industry_cnt     0.469621
# 43         employer_type_cnt     0.434800
# 44         num_employer_type     0.271094
# 45            del_in_18month     0.260459
# 46                        f1     0.155534
# 47          pub_dero_bankrup     0.100204
# 48       initial_list_status     0.083566
# 49                  app_type     0.040663
# 50                  is_train     0.000000
